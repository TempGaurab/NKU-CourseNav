# %%
data = {'RSP 331': ['RSP 310'], 'RSP 310': ['RSP 220'], 'RSP 220': ['RSP 201', 'RSP 201L', 'BIO 209L', 'BIO 209'], 'RSP 201': ['RSP 286', 'RSP 201L'], 'RSP 286': []}

# %%
data
# Out:
# {'RSP 331': ['RSP 310'],
#  'RSP 310': ['RSP 220'],
#  'RSP 220': ['RSP 201', 'RSP 201L', 'BIO 209L', 'BIO 209'],
#  'RSP 201': ['RSP 286', 'RSP 201L'],
#  'RSP 286': []}

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.DiGraph()
G

# %%
for course, prereqs in data.items():
    if not prereqs:
        G.add_node(course)
    else:
        for prereq in prereqs:
            G.add_edge(prereq, course)

# %%
# Set up the plot
plt.figure(figsize=(12, 8))

# Create a layout for the graph
pos = nx.spring_layout(G)

# %%
# Draw the graph
nx.draw(G, pos, with_labels=True, node_color='lightblue', 
        node_size=3000, font_size=10, font_weight='bold', 
        arrows=True, edge_color='gray')

# Add a title
plt.title("Course Prerequisite Graph", fontsize=16)

# Show the plot
plt.tight_layout()
plt.axis('off')
plt.show()
# Out:
# C:\Users\gauur\AppData\Local\Temp\ipykernel_1500\169925603.py:10: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
