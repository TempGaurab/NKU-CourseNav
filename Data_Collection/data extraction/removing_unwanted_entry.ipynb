# %%
file_path  = "course_urls.txt"

# %%
with open(file_path, 'r') as file:
            lines = file.readlines()

# %%
lines
# Out:
# ['http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=62111\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=62106\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=62088\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=61962\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=62212\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=62129\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=61844\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=60820\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=60821\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=61996\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=60825\n',
# ...

# %%
filtered_lines = [
    line for index, line in enumerate(lines)
    if len(line) <= 150
]
filtered_lines
# Out:
# ['http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=62111\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=62106\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=62088\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=61962\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=62212\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=62129\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=61844\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=60820\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=60821\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=61996\n',
#  'http://nku.catalog.acalog.com/preview_course_nopop.php?catoid=23&coid=60825\n',
# ...

# %%
with open('filtered_file.txt', 'w') as filtered_file:
    filtered_file.writelines(filtered_lines)
